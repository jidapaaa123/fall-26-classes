# %%
print(3+2)
# Out:
# 5

# %%
class Solution:
    def hasDuplicate(self, nums: List[int]) -> bool:
        return False


sol = Solution()
print(sol.hasDuplicate([1, 2, 3]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 class Solution:
#       2     def hasDuplicate(self, nums: List[int]) -> bool:
#       3         return False
#
# Cell In[2], line 2, in Solution()
#       1 class Solution:
# ----> 2     def hasDuplicate(self, nums: List[int]) -> bool:
#       3         return False
#
# NameError: name 'List' is not defined
